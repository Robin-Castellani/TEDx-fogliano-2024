# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
ROOT_FOLDER = Path("/home/robin/projects/TEDx/")

file_csv = ROOT_FOLDER / "data" / "Emissions" / "ghg-emissions.csv"

images_dir = Path(ROOT_FOLDER / "output" / "images" / "emission")
images_dir.mkdir(parents=True, exist_ok=True)

plt.style.use("default")

# %%
em = pd.read_csv(
    file_csv, skipfooter=2, engine="python", na_values="false", index_col="Settore"
)
em = em.drop(columns="unit")
em.head()
# Out:
#                                  1850   1851   1852   1853   1854   1855  \
# Settore
# Energia                          4.46   4.48   4.51   4.53   4.55   4.57
# Processi industriali e prodotti   NaN    NaN    NaN    NaN    NaN    NaN
# Agricoltura                      9.95  10.00  10.10  10.20  10.30  10.30
# Rifiuti                          1.23   1.24   1.25   1.25   1.26   1.27
#
#                                   1856   1857   1858   1859  ...   2013  \
# Settore                                                      ...
# Energia                           4.59   4.60   4.62   4.63  ...  367.0
# Processi industriali e prodotti    NaN    NaN    NaN    NaN  ...   36.7
# Agricoltura                      10.40  10.50  10.50  10.60  ...   31.5
# Rifiuti                           1.28   1.29   1.30   1.31  ...   18.6
#
#                                   2014   2015   2016   2017   2018   2019  \
# Settore
# Energia                          347.0  359.0  356.0  351.0  346.0  336.0
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 10), dpi=400)
em.T.plot.area(stacked=True, ax=ax)
ax.set_title("Emissioni totali di gas serra in Italia")
ax.set_xlabel("Anno")
ax.set_ylabel("Mt CO_2eq")
# Out:
# Text(0, 0.5, 'Mt CO_2eq')
